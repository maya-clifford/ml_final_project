# %% [markdown]
# # Liver Patient Dataset

# %%
# imports
import kagglehub
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read in the data

# %%
# !pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shauryasrivastava01/liver-patient-dataset")

print("Path to dataset files:", path)
# List files in the downloaded dataset directory
print(os.listdir(path))
# Out:
# Using Colab cache for faster access to the 'liver-patient-dataset' dataset.
# Path to dataset files: /kaggle/input/liver-patient-dataset
# ['liver_patient_dataset.csv']

# %%
df = pd.read_csv(os.path.join(path, "liver_patient_dataset.csv"))
df.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  \
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3       0.90
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2       0.74
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3       0.89
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4       1.00
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4       0.40
#
#         Selector
# 0  Liver Disease
# 1  Liver Disease
# 2  Liver Disease
# 3  Liver Disease
# 4  Liver Disease

# %%
# replace the target variable with 1 for positive class (liver disease) and 0 for negative class (no liver disease)
df['Selector'] = df['Selector'].replace({'Liver Disease':1, 'No Liver Disease':0})
# Out:
# /tmp/ipykernel_33686/1458033854.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Selector'] = df['Selector'].replace({'Liver Disease':1, 'No Liver Disease':0})

# %%
# change the name of the selector column to target
df.rename(columns={'Selector':'Target'}, inplace=True)
df.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Target
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3       0.90       1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2       0.74       1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3       0.89       1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4       1.00       1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4       0.40       1

# %%
# calculate the prevalance
prevalance = np.mean(df.Target) * 100
print(f'The prevalance is {prevalance:.2f}%')
# Out:
# The prevalance is 71.36%

# %%
# check for null values
print(df.isna().sum())
# Out:
# Age          0
# Gender       0
# TB           0
# DB           0
# Alkphos      0
# Sgpt         0
# Sgot         0
# TP           0
# ALB          0
# A/G Ratio    0
# Target       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        583 non-null    int64
#  1   Gender     583 non-null    object
#  2   TB         583 non-null    float64
#  3   DB         583 non-null    float64
#  4   Alkphos    583 non-null    int64
#  5   Sgpt       583 non-null    int64
#  6   Sgot       583 non-null    int64
#  7   TP         583 non-null    float64
#  8   ALB        583 non-null    float64
#  9   A/G Ratio  583 non-null    float64
#  10  Target     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
# print the summary statistics of the numeric data
df.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB   A/G Ratio      Target
# count   583.000000  583.000000  583.000000  583.000000  583.000000
# mean    109.910806    6.483190    3.141852    0.946947    0.713551
# std     288.918529    1.085451    0.795519    0.318495    0.452490
# min      10.000000    2.700000    0.900000    0.300000    0.000000
# 25%      25.000000    5.800000    2.600000    0.700000    0.000000
# 50%      42.000000    6.600000    3.100000    0.930000    1.000000
# 75%      87.000000    7.200000    3.800000    1.100000    1.000000
# max    4929.000000    9.600000    5.500000    2.800000    1.000000

# %% [markdown]
# From looking at the summary statistics, TB, DB, Alkphos, Sgpt and Sgot all need to be transformed so they have a more normal distribution. They are all clearly very skewed, as they have standard deviations that are much greater than the means and have max values that are much higher than the number that's the 75th percentile of the column. These are all skewed to the right so we will use log transformations on the columns.

# %%
to_transform = ['TB',	'DB',	'Alkphos',	'Sgpt',	'Sgot']
names = ['TB_log',	'DB_log',	'Alkphos_log',	'Sgpt_log',	'Sgot_log']
df[names] = np.log(df[to_transform])
df.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  A/G Ratio  Target  \
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3       0.90       1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2       0.74       1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3       0.89       1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4       1.00       1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4       0.40       1
#
#      TB_log    DB_log  Alkphos_log  Sgpt_log  Sgot_log
# 0 -0.356675 -2.302585     5.231109  2.772589  2.890372
# 1  2.388763  1.704748     6.549651  4.158883  4.605170
# 2  1.987874  1.410987     6.194405  4.094345  4.219508
# 3  0.000000 -0.916291     5.204007  2.639057  2.995732
# 4  1.360977  0.693147     5.273000  3.295837  4.077537

# %%
df.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB   A/G Ratio      Target  \
# count   583.000000  583.000000  583.000000  583.000000  583.000000
# mean    109.910806    6.483190    3.141852    0.946947    0.713551
# std     288.918529    1.085451    0.795519    0.318495    0.452490
# min      10.000000    2.700000    0.900000    0.300000    0.000000
# 25%      25.000000    5.800000    2.600000    0.700000    0.000000
# 50%      42.000000    6.600000    3.100000    0.930000    1.000000
# 75%      87.000000    7.200000    3.800000    1.100000    1.000000
# max    4929.000000    9.600000    5.500000    2.800000    1.000000
#
#            TB_log      DB_log  Alkphos_log    Sgpt_log    Sgot_log
# count  583.000000  583.000000   583.000000  583.000000  583.000000
# mean     0.463421   -0.650373     5.493417    3.751829    3.956771
# std      1.018527    1.326394     0.528128    0.900236    0.997381
# min     -0.916291   -2.302585     4.143135    2.302585    2.302585
# 25%     -0.223144   -1.609438     5.167635    3.135494    3.218876
# 50%      0.000000   -1.203973     5.337538    3.555348    3.737670
# 75%      0.955511    0.262364     5.697093    4.102609    4.465908
# max      4.317488    2.980619     7.654443    7.600902    8.502891
